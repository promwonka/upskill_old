# %%
import pandas as pd
df = pd.read_csv('data.csv')
import numpy as np
df
# Out:
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0      132512    22177                28         NaN               2
# 1      132513    21413                12         NaN               2
# 2      132514    22178                12         NaN               2
# 3      132515    13034                12         NaN               2
# 4      132517    22180                12         NaN               2
# ...       ...      ...               ...         ...             ...
# 43426  185937    14364                12         NaN               2
# 43427  185938    48727                12         NaN               2
# 43428  185939    48729                12         1.0               3
# 43429  185940    30724                87         NaN               2
# 43430  185941    48730                12         NaN               2
#
#        from_area_id  to_area_id  from_city_id  to_city_id         from_date  \
# ...

# %%
#df['Col1'].fillna(df['Col2'])

# %%
#df['package_id'] = df['travel_type_id'].apply(lambda x: 8 if x=3 else None )

# %%
df_test = df[df['from_city_id'] == 15]
df_test = df_test[df_test['travel_type_id'] != 1]
df_test.package_id.value_counts()
df_test
# Out:
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 24433  162581    33218                12         NaN               2
# 24434  162583    37529                12         NaN               2
# 24435  162585    37531                12         NaN               2
# 24436  162586    36411                12         NaN               2
# 24437  162587    36411                12         NaN               2
# ...       ...      ...               ...         ...             ...
# 43426  185937    14364                12         NaN               2
# 43427  185938    48727                12         NaN               2
# 43428  185939    48729                12         1.0               3
# 43429  185940    30724                87         NaN               2
# 43430  185941    48730                12         NaN               2
#
#        from_area_id  to_area_id  from_city_id  to_city_id         from_date  \
# ...

# %%
df_package3.from_city_id.value_counts()
# Out:
# 15.0    448
# Name: from_city_id, dtype: int64

# %%
df_package3.tail(50)
# Out:
#            id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 43276  185766    48629                12         1.0               3
# 43279  185769    34823                12         3.0               3
# 43280  185772    41939                65         7.0               3
# 43282  185774    30716                12         1.0               3
# 43284  185778    48637                65         2.0               3
# 43285  185779    48638                65         4.0               3
# 43286  185780    48639                24         4.0               3
# 43293  185787    46354                12         1.0               3
# 43295  185790    40643                65         2.0               3
# 43300  185795     9964                65         1.0               3
# 43301  185796    14903                12         1.0               3
# 43302  185798    48591                65         4.0               3
# 43307  185805    22839                12         1.0               3
# ...

# %%
df_package3.isna().sum()
# Out:
# id                        0
# user_id                   0
# vehicle_model_id          0
# package_id                0
# travel_type_id            0
# from_area_id              0
# to_area_id             7550
# from_city_id           7102
# to_city_id             7550
# from_date                 0
# to_date                2620
# online_booking            0
# mobile_site_booking       0
# booking_created           0
# from_lat                  0
# from_long                 0
# to_lat                 7550
# to_long                7550
# Car_Cancellation          0
# dtype: int64

# %%
df_package.package_id.value_counts()
# Out:
# 1.0    3503
# 2.0    2651
# 6.0     502
# 4.0     412
# 3.0     375
# 7.0     101
# 5.0       6
# Name: package_id, dtype: int64

# %%
# within city limits

# %%
df_package3 = df[df['travel_type_id'] == 3]

# %%
df_package3['to_area_id'] = 'NA'
df_package3['to_city_id'] = 'NA'
df_package3['from_city_id'] = 15.0 #on the pretext only this city provides hourly rides
df_package3['to_lat'] = 'NA'
df_package3['to_long'] = 'NA'
# Out:
# <ipython-input-417-364394abb985>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package3['to_area_id'] = 'NA'
# <ipython-input-417-364394abb985>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package3['to_city_id'] = 'NA'
# <ipython-input-417-364394abb985>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_package3['to_city_id'] = df_package3['from_city_id']
# Out:
# <ipython-input-310-d84f06917ad9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package3['to_city_id'] = df_package3['from_city_id']

# %%
# Out:
# <ipython-input-311-90b871431a0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package3['to_lat'] = df_package3['from_lat']
# <ipython-input-311-90b871431a0e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package3['to_long'] = df_package3['from_long']

# %%
df_package3['from_city_id'] = df_package3['from_city_id'].fillna('Same Area')
df_package3['to_city_id'] = df_package3['to_city_id'].fillna('Same Area')
# Out:
# <ipython-input-312-df925b24123f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package3['from_city_id'] = df_package3['from_city_id'].fillna('Same Area')
# <ipython-input-312-df925b24123f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package3['to_city_id'] = df_package3['to_city_id'].fillna('Same Area')

# %%
df['Dates'] = pd.to_datetime(df['Dates'], format='%y%m%d')

# %%
df_package2 = df[df['travel_type_id'] == 2]

# %%
df_package2.isna().sum()
# Out:
# id                         0
# user_id                    0
# vehicle_model_id           0
# package_id                 0
# travel_type_id             0
# from_area_id               0
# to_area_id                 0
# from_city_id               0
# to_city_id                 0
# from_date                  0
# to_date                15185
# online_booking             0
# mobile_site_booking        0
# booking_created            0
# from_lat                   0
# from_long                  0
# to_lat                     0
# to_long                    0
# Car_Cancellation           0
# dtype: int64

# %%
df_package2
# Out:
#            id  user_id  vehicle_model_id      package_id  travel_type_id  \
# 0      132512    22177                28  Point to Point               2
# 1      132513    21413                12  Point to Point               2
# 2      132514    22178                12  Point to Point               2
# 3      132515    13034                12  Point to Point               2
# 4      132517    22180                12  Point to Point               2
# ...       ...      ...               ...             ...             ...
# 43425  185936    30220                12  Point to Point               2
# 43426  185937    14364                12  Point to Point               2
# 43427  185938    48727                12  Point to Point               2
# 43429  185940    30724                87  Point to Point               2
# 43430  185941    48730                12  Point to Point               2
#
#        from_area_id  to_area_id from_city_id to_city_id         from_date  \
# ...

# %%
df_package2['package_id'] = 'Point to Point'
# Out:
# <ipython-input-321-06ac00176f6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package2['package_id'] = 'Point to Point'

# %%
df_package2['to_city_id'] = df_package2['from_city_id']
# Out:
# <ipython-input-325-9e73d6cb949c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package2['to_city_id'] = df_package2['from_city_id']

# %%
df_package2['from_city_id'] = df_package2['from_city_id'].fillna('Same Area')
df_package2['to_city_id'] = df_package2['to_city_id'].fillna('Same Area')
# Out:
# <ipython-input-327-b2528f95747f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package2['from_city_id'] = df_package2['from_city_id'].fillna('Same Area')
# <ipython-input-327-b2528f95747f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package2['to_city_id'] = df_package2['to_city_id'].fillna('Same Area')

# %%
df_package1 = df[df['travel_type_id'] == 1]

# %%
df_package1.isna().sum()
# Out:
# id                       0
# user_id                  0
# vehicle_model_id         0
# package_id               0
# travel_type_id           0
# from_area_id             0
# to_area_id               0
# from_city_id           196
# to_city_id               1
# from_date                0
# to_date                 85
# online_booking           0
# mobile_site_booking      0
# booking_created          0
# from_lat                93
# from_long               93
# to_lat                  93
# to_long                 93
# Car_Cancellation         0
# dtype: int64

# %%
df_package1.tail(50)
# Out:
#            id  user_id  vehicle_model_id     package_id  travel_type_id  \
# 42054  184247    47835                65  long distance               1
# 42090  184288    45184                65  long distance               1
# 42107  184312    47869                87  long distance               1
# 42117  184331    47882                12  long distance               1
# 42185  184415    47911                89  long distance               1
# 42192  184423    47917                12  long distance               1
# 42193  184424    47919                12  long distance               1
# 42199  184432    32286                65  long distance               1
# 42212  184452    47940                12  long distance               1
# 42222  184465    47940                12  long distance               1
# 42230  184475    47946                12  long distance               1
# 42269  184526    47969                12  long distance               1
# ...

# %%
df_package1['package_id'] = 'long distance'
# Out:
# <ipython-input-357-4c2a1de4d971>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package1['package_id'] = 'long distance'

# %%
df_package1['to_area_id'] = df_package1['from_area_id']
# Out:
# <ipython-input-358-21c72cfbdede>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package1['to_area_id'] = df_package1['from_area_id']

# %%
df_package1['from_area_id'] = df_package1['from_area_id'].fillna('Same Area')
df_package1['to_area_id'] = df_package1['to_area_id'].fillna('Same Area')
# Out:
# <ipython-input-359-473915aa6be2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package1['from_area_id'] = df_package1['from_area_id'].fillna('Same Area')
# <ipython-input-359-473915aa6be2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package1['to_area_id'] = df_package1['to_area_id'].fillna('Same Area')

# %%
df_package1['to_lat'] = df_package1['from_lat']
df_package1['to_long'] = df_package1['from_long']
# Out:
# <ipython-input-362-da8c39665e1b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package1['to_lat'] = df_package1['from_lat']
# <ipython-input-362-da8c39665e1b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package1['to_long'] = df_package1['from_long']

# %%
# Out:
# <ipython-input-366-c930da6d0e7f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package1['from_lat'] = df_package1['from_lat'].fillna('Same Area')
# <ipython-input-366-c930da6d0e7f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_package1['to_lat'] = df_package1['to_lat'].fillna('Same Area')
